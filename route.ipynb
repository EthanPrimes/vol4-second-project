# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# Load lakes shapefile
lakes = gpd.read_file("data/ne_10m_lakes.shp")

# Filter for Lake Michigan
lake_michigan = lakes[lakes["name"] == "Lake Michigan"]

# Plot
lake_michigan.plot()
plt.show()
